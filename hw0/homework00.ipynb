# %% [markdown]
# <style>
#     @media print{
#         body {
#             position:relative !important;
#         }
#         .celltag_new_page {
#             page-break-before: always !important;
#         }
#     }
# </style>
# # COMPSCI 527 Homework 0

# %% [markdown]
# $
# %helpful commands
# \newcommand{\t}{^{\intercal}}
# \newcommand{\transp}[2]{{#1}\t{#2}}
# \newcommand{\dotp}[2]{\vec{#1}\centerdot \vec{#2}}
# $

# %% [markdown]
# ### Problem 0 (3 points)

# %% [markdown]
# ## Part 1: Eigenvalues and Eigenvectors

# %% [markdown]
# ### Problem 1.1

# %% [markdown]
# We define orthogonality by the dot product of the two real eigenvectors $\vec{v_1}, \vec{v_2}$ as the following:
#
# $
# \begin{equation*}
# \dotp{v_1}{v_2} := \transp{v_1}{v_2} = 0
# \end{equation*}
# $

# %% [markdown]
# We also define eigenvectors by the following equation, where $Q$ is some symmetric, real matrix and $\vec{v_1} \ne \vec{0}$:
#
# $$ Q\vec{v_1} = \lambda\vec{v_1} $$

# %% [markdown]
# We can take the dot product of each side of each equation with the transpose of the opposing eigenvector like so:
#
# $$
# Q \vec{v_1} = \lambda_1\vec{v_1} \\
# Q \vec{v_2} = \lambda_2\vec{v_2} \\
# \downarrow \\
# \vec{v_2}\t Q \vec{v_1} = \lambda_1\transp{v_2}{v_1}\\
# \vec{v_1}\t Q \vec{v_2} = \lambda_2\transp{v_1}{v_2}\\
# $$

# %% [markdown]
# We can take the transpose of either of the equations to match the other. For example:
#
# $$
# \vec{v_2}\t Q \vec{v_1} = \lambda_1 \transp{v_2}{v_1} \\
# \underrightarrow{\text{transpose}} \\
# \vec{v_1}\t Q \vec{v_2} = \lambda_1 \transp{v_1}{v_2} \\
# $$

# %% [markdown]
# Now, we can subtract the transposed result from its matching equation to set the left side to zero:
#
# $$ 0 = \lambda_1 \transp{v_1}{v_2} - \lambda_1 \transp{v_1}{v_2} $$
#
# Which, simplified, leaves:
#
# $$ 0 = (\lambda_1 - \lambda_2)\transp{v_1}{v_2} $$

# %% [markdown]
# We are given that $\lambda_1 > \lambda_2$; therefore, the difference $\lambda_1 - \lambda_2$ is nonzero.
#
# Therefore, we can conclude that $\transp{v_1}{v_2} = 0 $, which is only true if the vectors are orthogonal.
#
# <b> Therefore, two eigenvectors are orthogonal under the given conditions. </b>

# %% [markdown]
# ### Problem 1.2

# %% [markdown]
# Using Lagrange multipliers, we can prove that the unit vector $\vec{x}$ represent the eigenvectors with the largest and smallest eigenvalues when $q(\vec{x}) = \vec{x}\t Q \vec{x}$ is maximized and minimized.

# %% [markdown]
# Let the objective function be:
#
# $$q(\vec{x}) = \vec{x}\t Q\vec{x}$$

# %% [markdown]
# Let the constraint function be:
#
# $$g(\vec{x}) = |\vec{x}|^2 - 1 = 0$$

# %% [markdown]
# Let $q_x$ denote the partial derivative of $q(\vec{x})$, $g_x$ denote the partial derivative of g(x), and $\lambda$ as the multiplier, we solve for:
#
# $$q_x = \lambda g_x$$

# %% [markdown]
# From the definition of our constraint, we have:
#
# $$g_x(\vec{x}) = 2\vec{x}$$

# %% [markdown]
# And the partial derivative of $q(\vec{x})$ would be:
#
# $$q_x(\vec{x}) = Q\vec{x} + (\vec{x}\t Q)\t = 2Q\vec{x}$$

# %% [markdown]
# Substituting these into the Lagrangian yields:
#
# $$\lambda 2\vec{x} = 2Q\vec{x}$$
#
# $$\lambda \vec{x} = Q\vec{x}$$

# %% [markdown]
# Here we can see that the Lagrangian multiplier can also represent the eigenvalue with $\vec{x}$ its associated eigenvector.
# Since $q(\vec{x})=\vec{x}\t Q\vec{x}$,
#
# $$q(\vec{x}) = \lambda \transp{x}{x} = \lambda ||\vec{x}|| = \lambda $$

# %% [markdown]
# Since we are maximizing and minimizing $q(\vec{x})$ for all unit vectors $\vec{x}$, we are essentially maximizing and minimizing $\lambda$. Therefore, the associated eigenvectors of $\lambda_1$ and $\lambda_2$ are the eigenvectors with the largest and smallest eigenvalue.

# %% [markdown]
# ### Problem 1.3

# %% [markdown]
# Say the set of all real and symmetric matrices with equal eigenvalues is given by:
#
# $$
# Q =
# \begin{bmatrix}
# r & s \\
# s & t \\
# \end{bmatrix}
# $$

# %% [markdown]
# The objective is to determine under what conditions of $r$,$s$ and $t$ will the eigenvalues $\lambda_1$ and $\lambda_2$ of $Q$ become equal. That is:
#
# $$ \lambda_1 = \lambda_2 $$

# %% [markdown]
# Going by the definition given to evaluate the eigenvalues of a matrix, we have:
#
# $$|Q - \lambda I| = 0$$
# <br>
# $$
# \begin{vmatrix}
# \begin{bmatrix}
# r & s \\
# s & t
# \end{bmatrix} -
# \begin{bmatrix}
# λ & 0 \\
# 0 & λ
# \end{bmatrix}
# \end{vmatrix}
# = 0
# $$
# <br>
# $$
# \begin{vmatrix}
# {r - λ} & s \\
# s & {t - λ} \\
# \end{vmatrix}
# = 0
# $$
# <br>
# $$
# \begin{equation*}
# (r - λ)(t - λ) - s^{2} = 0
# \tag{1}
# \label{eq:1.3:1}
# \end{equation*}
# $$

# %% [markdown]
# On expanding the equation, we obtain a quadratic equation in the variable $\lambda$:
#
# $$\lambda^{2} - (r + t)\lambda + (rt - s^{2}) = 0$$

# %% [markdown]
# If $\lambda_1 = \lambda_2$, then the discriminant of the above equation has to be 0.
#
# $$(r - t)^{2} + 4s^{2} = 0$$

# %% [markdown]
# By taking $4s^{2}$ on the left-hand-side and taking the square root, we will obtain complex solutions to the values of $r$,$s$ and $t$. However, that is not possible since the given data claims that the given matrix is real-valued.
#
# Hence, the only real solutions to the equation occurs when:
#
# $$
# r = t,
# s = 0,
# r \in \mathbb{R}
# $$
#
# That is,
#
# **the set of all real-valued symmetric matrices with equal eigenvalues are essentially scalar matrices.**
#
# $$
# Q =
# \begin{bmatrix}
# r & 0 \\
# 0 & r \\
# \end{bmatrix}
# $$

# %% [markdown]
# The eigenvalues of scalar matrices are obtained by equation $\eqref{eq:1.3:1}$:
#
# $$(r - λ)(r - λ) = 0$$
# $$λ = r$$

# %% [markdown]
# **The eigenvalues of scalar matrices are equal to the diagonal elements of the given matrix.**

# %% [markdown]
# Say the unit-norm eigenvector corresponding to $\lambda_1$ is $\vec{v_1}$. By defition of eigenvalues and eigenvectors:
#
# $$Q\vec{v_1} = \lambda_1\vec{v_1}$$
#
# $$
# \begin{bmatrix}
# r & 0 \\
# 0 & r
# \end{bmatrix}
# $$
#
# $$\vec{v_1} = r\vec{v_1}$$
#
# It is clear that there is no unique eigenvector which satsifies the given condition.

# %% [markdown]
# **There are infinitely many unit-norm eigenvectors for the given type of matrices and eigenvalues.**
#
# This is also justified by the fact that real-symmetric matrices perform a linear transformation on vectors that only perform scaling function. The elements of these matrices, also the eigenvalues, correspond to the change in the magnitude of these vectors alone as the diretion continues to remain unchanged. Hence, there exist infinite eigenvectors under such conditions.

# %% [markdown]
# ## Part 2: Singular Values and Singular Vectors

# %% [markdown]
# ### Problem 2.1

# %% [markdown]
# The newly obtained vectors post the linear tranformation are described as follows:
#
# $$
# \begin{equation*}
# \vec{y_1} = \sigma_1\vec{u_1}
# \tag{1}
# \label{eq:2.1:1}
# \end{equation*}
# $$
#
# $$
# \begin{equation*}
# \vec{y_2} = \sigma_2\vec{u_2}
# \tag{2}
# \label{eq:2.1:2}
# \end{equation*}
# $$

# %% [markdown]
# **To Prove:**
#
# $\vec{u_{1}}$ and $\vec{u_{2}}$ are perpendicular to each other. That is, the dot product of these vectors is zero:
#
# $$
# \dotp{u_1}{u_2} = \transp{u_1}{u_2} = \transp{u_2}{u_1} = 0
# $$

# %% [markdown]
# **Proof:**

# %% [markdown]
# Taking transpose of equation $\eqref{eq:2.1:2}$:
#
# $$
# \begin{equation*}
# \vec{y_2}\t = \sigma_2\vec{u_2}\t
# \tag{3}
# \label{eq:2.1:3}
# \end{equation*}
# $$

# %% [markdown]
# Multiplying $\eqref{eq:2.1:1}$ with $\eqref{eq:2.1:3}$:
#
# $$
# \begin{equation*}
# \transp{y_2}{y_1} =
# \sigma_2\vec{u_2}\t\sigma_1\vec{u_1} =
# \sigma_1\sigma_2\transp{u_2}{u_1}
# \tag{4}
# \label{eq:2.1:4}
# \end{equation*}
# $$

# %% [markdown]
# We also know that the longest vectors $\vec{y_1}$ and $\vec{y_2}$ are expressed as:
#
# $$\vec{y_1} = A\vec{v_1}$$
# $$\vec{y_2} = A\vec{v_2}$$

# %% [markdown]
# Substituting the above in $\eqref{eq:2.1:4}$:
#
# $$\vec{v_2}\t A\t A\vec{v_1} = \sigma_1\sigma_1\transp{u_2}{u_1}$$

# %% [markdown]
# It is known that:
#
# $$Q = A\t A$$
#
# The eigenvalues of $Q$ are $\lambda_1$ and $\lambda_2$. The corresponding eigenvectors are $\vec{v_1}$ and $\vec{v_2}$ respectively.

# %% [markdown]
# This implies:<br>
# $$\vec{v_2}\t Q\vec{v_1} = \sigma_1 \sigma_2 \transp{u_2}{u_1}$$
#
# But,
#
# $$Q\vec{v_1} = \lambda_1\vec{v_1} $$

# %% [markdown]
# The final equation computes to:
#
# $$\lambda_1\transp{v_2}{v_1} = \sigma_1 \sigma_2 \transp{u_2}{u_1}$$

# %% [markdown]
# Remembering that $\vec{v_1}$ and $\vec{v_2}$ are mutually orthogonal vectors,
#
# $$\transp{v_2}{v_1} = 0$$

# %% [markdown]
# Therefore,
# $$\sigma_1 \sigma_2 \transp{u_2}{u_1} = 0$$
#
# Since the eigenvalues are non-zero, $\lambda_1$ and $\lambda_2$, $\sigma_1$ and $\sigma_2$ are also non-zero.

# %% [markdown]
# Hence,
#
# $$\transp{u_2}{u_1} = 0 = \dotp{u_2}{u_1} $$
#
# **$\vec{u_1}$ and $\vec{u_2}$ are thus perpendicular to one another.**

# %% [markdown]
# ### Problem 2.2

# %% [markdown]
# **Given:**
#
# $$\vec{y} = A\vec{x}$$

# %% [markdown]
# **To derive:**
#
# Equation of the ellipse $E$, that confirms to the below condition, in terms of $A$:
#
# $$
# \vec{y}\t E \vec{y} = 1
# $$

# %% [markdown]
# **Method:**

# %% [markdown]
# We are given that
#
# $$
# \begin{equation*}
# \vec{y} = A\vec{x}
# \tag{1}
# \label{eq:2.2:1}
# \end{equation*}
# $$

# %% [markdown]
# Multiplying $\eqref{eq:2.2:1}$ with $A\t$:
#
# $$
# \begin{equation*}
# A\t \vec{y} = A\t A\vec{x}
#
# \tag{2}
# \label{eq:2.2:2}
#
# \end{equation*}
# $$

# %% [markdown]
# But it is known that
#
# $$Q = A\t A$$

# %% [markdown]
# Substituting in $\eqref{eq:2.2:2}$:
#
# $$
# \begin{equation*}
# A\t\vec{y} = Q\vec{x}
# \tag{3}
# \label{eq:2.2:3}
# \end{equation*}
# $$

# %% [markdown]
# Multiplying $\eqref{eq:2.2:3}$ with $Q^{-1}$:
#
# $$
# \begin{equation*}
# Q^{-1} A\t \vec{y} = \vec{x}
# \tag{4}
# \label{eq:2.2:4}
# \end{equation*}
# $$

# %% [markdown]
# Taking transpose of $\eqref{eq:2.2:4}$:
#
# $$
# \begin{equation*}
# \vec{y}\t A(Q^{-1})\t = \vec{x}\t
# \tag{5}
# \label{eq:2.2:5}
# \end{equation*}
# $$

# %% [markdown]
# The area under consideration is a unit-circle with $\vec{x}$ as the radius. This gives:
#
# $$\transp{x}{x} = 1$$

# %% [markdown]
# Multiplying $\eqref{eq:2.2:5}$ with $\eqref{eq:2.2:4}$:
#
# $$\transp{x}{x} = \vec{y}\t A(Q^{-1})\t Q^{-1} A\t \vec{y} = 1$$

# %% [markdown]
# Equating this to:
#
# $$\vec{y}\t E \vec{y} = 1$$

# %% [markdown]
# We get:
#
# $$E = A (Q^{-1})\t Q^{-1} A\t$$

# %% [markdown]
# ### Problem 2.3

# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

def ellipse(a):
    '''
    using input 3x2 matrix, the function multiplies the matrix
    with coordinates passed in as a nx2 vector describing an ellipse (i.e. a
    R^2 vector with n coordinates). The returned matrix is therefore 3xn in
    dimensions, and represents the vector transformed by the matrix.
    '''

    assert np.all(a.shape == (3, 2)), 'matrix must be 3 x 2'

    n = 100

    # Generates coordinates for the unit vector x = <cos(x), sin(x)>,
    # as x^Tx = 1 indicates that x is a vector anywhere on the unit circle
    # converts coordinates to numpy array and transposes the matrix

    x_coords = [[np.cos(t), np.sin(t)] for t in range(n)] # 2 x 100 matrix
    x_coords = np.array(x_coords).T
    y_coords = np.matmul(a, x_coords)              # y = matrix A * vector x
    return y_coords

def draw_3d_curve(y):
    fig = plt.figure(figsize=(12, 10))
    ax = fig.gca(projection='3d')
    ax.plot(y[0], y[1], y[2])
    axes = ['x','y','z']
    ranges = [np.ptp(yk) for yk in y]
    ax.set_box_aspect(ranges)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.show()

a0 = np.array([[3., 1.], [0., 2.], [1., 0.]])

a0x = ellipse(a0)     # generate R^3 ellipse
draw_3d_curve(a0x)    # draw plot

# %% [markdown]
# ## Part 3: The Singular Value Decomposition

# %% [markdown]
# ### Problem 3.1

# %% [markdown]
# The cross product of two vectors is orthogonal to both. Take cross product of $\vec{u}$ and $\vec{v}$:
#
# $$ \vec{u} \times \vec{v} =
# \begin{bmatrix}
# 1 \\
# 0 \\
# 0 \\
# \end{bmatrix}
# \times
# \begin{bmatrix}
# 0\\
# \frac{\sqrt{3}}{2} \\
# \frac{1}{2} \\
# \end{bmatrix} =
# \begin{bmatrix}
# 0 \\
# -\frac{1}{2} \\
# \frac{\sqrt{3}}{2} \\
# \end{bmatrix}
# $$

# %% [markdown]
# ### Problem 3.2

# %% [markdown]
# We modify $\Sigma$ so that its dimensions are $3 \times 2$ by adding a row of zeros to the matrix. This collapses $\vec{u_3}$ to a point.
#
#
# $$\Sigma =
# \begin{bmatrix}
# \sigma_1 & 0 \\
# 0 & \sigma_2 \\
# 0 & 0 \\
# \end{bmatrix}$$

# %% [markdown]
# ## Part 4: Calculus

# %% [markdown]
# ### Problem 4.1

# %% [markdown]
# We can constrain the given function $f(x,y) = y(y-2x^2)$ to all values $ y = mx $. The resulting function is therefore $\phi_m(x) = (mx)^2 - 2mx^3$.

# %% [markdown]
# From here, we can examine the extrema of the function located at the roots of the derivative $\phi_m(x') = 2m^2x - 6mx^2$, and the concavity of the function around those extrema with the second derivative $\phi_m(x'') = 2m^2 -12mx$.

# %% [markdown]
# The zeros of $f'(x)$ are easily found by factoring the derivative to the following:
#
# $ 2mx(m-3x) = 0 $
#
# This equation has the solutions $ x = 0, x = \frac{m}{3} $. Therefore, along the line $ y = mx $, the point $(0,0)$ is some extrema.

# %% [markdown]
# Likewise, there is a single zero on second derivative, indicating a single inflection point. This point is:
#
# $ 2m(m - 6x) = 0 $
#
# This equation has the solution $ x = \frac{m}{6} $.

# %% [markdown]
# Now, we can split up $m$ into a set of critical intervals. To reason about what intervals we should establish, we have to consider the behavior of the function.

# %% [markdown]
# As a third degree polynomial, the function has at most three roots, two extrema, and one inflection point, regardless of the value of $m$.

# %% [markdown]
# We are investigating the point at which $ y = 0 $, which is only true if $ x = 0 $ or $ m = 0 $ by $ y = mx $. Therefore, we want to look around the point $ y = 0 $ when $ m = 0 $, or when $ x = 0 $ and $m \in \mathbb{R}$. Therefore, we can set up the following table for the value of the function $\phi_m(x)$ and its derivatives:

# %% [markdown]
# | $m$            | $\phi_m(x)$      | $\phi_m(x')$    | $\phi_m(x'')$ |
# | :---:          | :------:         | :-------:       | :--------:    |
# | $(-\infty, 0)$ | $(mx)^2 + 2mx^3$ | $2m^2x + 6mx^2$ | $2m^2 + 12mx$ |
# | $= 0$          | $0$              | $0$             | $0$           |
# | $(0, +\infty)$ | $(mx)^2 - 2mx^3$ | $2m^2x - 6mx^2$ | $2m^2 - 12mx$ |

# %% [markdown]
# We can make a few conclusions from this table. Most obviously, when $ m = 0 $, $\phi_m(x) = 0$ for any $x \in \mathbb{R}$. This resolves our first case proposed.

# %% [markdown]
# When $ m < 0 $, the function's highest degree flips sign. Though this has implications on the location of the other extremum ($x = \frac{m}{6}$; it reflects it across the $y$ axis), this doesn't affect the location of the extremum we are investigating at $x = 0$, compared to when $m > 0$. Therefore, for $m \in (-\infty, 0) \cup (0, +\infty)$, the concavity at the point $ y = 0 $ is consistent.

# %% [markdown]
# Specifically, the concavity at the point $ y = 0 $ is determined by the value of $\phi_m(x'')$ at the point (0,0). $\phi_m(0) = 2m^2$ is always positive for $m \in (-\infty, 0) \cup (0, +\infty)$; therefore, the point at y = 0 is always concave up, indicating a minimum.

# %% [markdown]
# Finally, we must determine the nature of the minimum at $ y = 0 $. In simple terms, a weak minimum is one where the value of $ x $ at the minimum is seen "around" that minimum along the function $f(x)$. We can disprove a weak minimum around $x = 0$ easily, by remembering that if the second order derivative continues to either positive or negative infinity on both ends, then the optimum is strict. Since $\phi_m(x'') = 2m^2$ is quadratic, its limits are the same sign and approach$\infty$ at both ends of the function. We can therefore conclude that the point $(0,0)$ is a strict local minimum for $m \ne 0, m \in \mathbb{R} $. At $m = 0$, the function resolves to $\phi_m(x) = 0$, a flat line (both a weak maximum and a weak minimum).

# %% [markdown]
# ### Problem 4.2

# %% [markdown]
# For the function $f(x,y) = y(y-2x^2)$, the Hessian matrix ($H_f(x)$) and gradient ($\nabla f(x,y)$) are the following:

# %% [markdown]
# $H_f(x) =
# \begin{bmatrix}
# \frac{\delta^2 f}{\delta x^2} & \frac{\delta^2 f}{\delta x \delta y} \\
# \frac{\delta^2 f}{\delta x \delta y} & \frac{\delta^2 f}{\delta y^2} \\
# \end{bmatrix}
# \rightsquigarrow
# \begin{bmatrix}
# -4y & -4x \\
# -4x & 2 \\
# \end{bmatrix}
# $

# %% [markdown]
# $\nabla f(x,y) = \langle f_x(x), f_y(y) \rangle
# \rightsquigarrow
# \langle -4xy, 2y-2x^2 \rangle$

# %% [markdown]
# At the point $(x,y) = (0,0)$, these resolve to:

# %% [markdown]
# $
# H_f(0) = \begin{bmatrix}
# 0 & 0 \\
# 0 & 2 \\
# \end{bmatrix}
# $

# %% [markdown]
# $\nabla f(0,0) = \langle 0, 0 \rangle$

# %% [markdown]
# ### Problem 4.3

# %% [markdown]
# To determine the type of point present at $(x,y) = (0,0)$, we will need to use an alternative approach compared to 4.1, as the function is no longer limited to a special case where $y$ is limited by $x$ to a single dimension. To do this, we can find the eigenvalues of the Hessian, which, depending on their values, may provide additional information.

# %% [markdown]
# The eigenvalues of the Hessian are given by the equation
#
# $ H_f(x)\vec{x} = \lambda\vec{x} $
#
# whose solutions can be obtained by taking the determinant of $H_f(x) - I(\lambda) = 0$.

# %% [markdown]
# This solution is therefore:
#
#
# $$
# \begin{bmatrix}
# 0 & 0 \\
# 0 & 2 \\
# \end{bmatrix}
# -
# \begin{bmatrix}
# \lambda & 0 \\
# 0 & \lambda \\
# \end{bmatrix}
# \rightsquigarrow
# \begin{bmatrix}
# -\lambda & 0 \\
# 0 & 2-\lambda \\
# \end{bmatrix}
# $$
#
# <br>
#
# $$
# det(
# \begin{bmatrix}
# -\lambda & 0 \\
# 0 & 2-\lambda \\
# \end{bmatrix}
# ) = 0
# \rightsquigarrow
# -\lambda(2-\lambda) = 0
# $$
#
# <br>
#
# Thus, the eigenvalues of this function are $\lambda_1 = 0, \lambda_2 = 1$.

# %% [markdown]
# This case of the Hessian, where one or more of the values are zero, is an indeterminate case. Therefore, we cannot use the Hessian to determine the type of point $(0,0)$ is.

# %% [markdown]
# Since the gradient is zero, we can determine at least that the point is a stationary point, meaning we are left with three options:
#
# 1. A saddle point,
# 2. A minimum, or
# 3. A maximum.

# %% [markdown]
# To make dealing with this question simpler, we can take a look at the function to examine it graphically and attempt to classify it by inspection.

# %%
from mpl_toolkits import mplot3d

# %matplotlib inline

import jupyter
import numpy as np
import matplotlib.pyplot as plt


def f(x, y):                               #the function
  return y*(y - 2*x**2)


fig = plt.figure()
ax = plt.axes(projection = "3d")

xy_bounds = np.linspace(-(10**10),10**10, 10**2)
x, y = xy_bounds, xy_bounds
x_ax, y_ax = np.meshgrid(x, y)            #building grid

z_ax = f(x_ax, y_ax)

ax.plot_surface(
    x_ax, y_ax, z_ax, 
    rstride = 1, cstride = 1, 
    cmap = 'inferno')

ax.scatter(0,0,0, c = "blue")

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x,y)')
# Out:
# Text(0.5, 0, 'f(x,y)')

# %% [markdown]
# From our graph above, we can see that the point (seen here in the center of the space) is located in a position where it is neither a minimum (as there are points nearby less than the value of $f(x,y)$ at $(0,0)$) nor a maximum (as there are points nearby greater than the value of $f(x,y)$ at $(0,0)$). Therefore, we conclude by inspection that the point is a saddle point.
